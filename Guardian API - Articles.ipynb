# %%
import pandas as pd
import numpy as np
import glob
from tqdm.notebook import tqdm_notebook
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Articles
# ## Filtering, preprocessing and exploratory analysis

# %% [markdown]
# The cell below loads the json files into one pandas dataframe called `data`. Data has 13 columns (variables) and 11,479 rows.

# %%
path_to_json = 'tempdata/articles/*.json'
json_file_list = glob.glob(path_to_json)
data = pd.DataFrame()
for json in json_file_list:
    temp = pd.read_json(json)
    data = data.append(temp, ignore_index=True)
org_no_articles = len(data)

# %% [markdown]
# `data` has one column called fields (`data.fields`), in which a lot of information about the article is stored, including, text, author,commentable and wordcount. In order to extract this information and add it to the existing dataframe we run the code in the following cell, adding 34 new columns to the dataframe.

# %%
data2 = pd.json_normalize(data.fields)
data = pd.merge(data, data2, left_index=True, right_index=True)

# %% [markdown]
# By running the code below you can check the first 5 and last 5 rows of `data` and see it's 34 variables.

# %%
data
# Out:
#                                                       id      type  \
# 0      commentisfree/2019/dec/10/doctor-johnson-thous...   article
# 1      sport/2019/dec/31/sport-in-2020-calendar-your-...   article
# 2      world/2020/jan/09/chinas-sars-like-illness-wor...   article
# 3      world/2020/jan/14/case-of-mystery-coronavirus-...   article
# 4      world/2020/jan/18/coronavirus-what-airport-mea...   article
# ...                                                  ...       ...
# 11474  business/live/2020/may/18/markets-rally-federa...  liveblog
# 11475  society/2020/may/18/disabled-people-in-uk-thre...   article
# 11476  world/live/2020/may/18/coronavirus-live-news-r...  liveblog
# 11477  world/live/2020/may/18/uk-coronavirus-live-loc...  liveblog
# 11478  world/2020/may/18/forces-allied-to-libyan-gove...   article
#
#            sectionId sectionName    webPublicationDate  \
# 0      commentisfree     Opinion  2019-12-10T17:43:16Z
# 1              sport       Sport  2019-12-31T20:00:44Z
# 2              world  World news  2020-01-09T19:10:17Z
# 3              world  World news  2020-01-14T06:44:02Z
# 4              world  World news  2020-01-18T09:21:23Z
# ...              ...         ...                   ...
# 11474       business    Business  2020-05-18T10:25:43Z
# 11475        society     Society  2020-05-18T10:26:18Z
# 11476          world  World news  2020-05-18T10:27:20Z
# 11477       politics    Politics  2020-05-18T10:29:41Z
# 11478          world  World news  2020-05-18T10:35:27Z
#
#                                                 webTitle  \
# 0      As a doctor I have to speak out: Johnson has c...
# 1      Sport in 2020 calendar: your month-by-month gu...
# 2       China's Sars-like illness worries health experts
# 3      Case of mystery Sars-like illness found outsid...
# 4      Coronavirus: what airport measures are in plac...
# ...                                                  ...
# 11474  Markets rally as Fed's Powell pledges more amm...
# 11475  Disabled people in UK threatened with sack unl...
# 11476  Coronavirus live news: Italy begins reopening ...
# 11477  UK coronavirus live: self-isolate if you lose ...
# 11478  Forces allied to Libyan government retake key ...
#
#                                                   webUrl  \
# 0      https://www.theguardian.com/commentisfree/2019...
# 1      https://www.theguardian.com/sport/2019/dec/31/...
# 2      https://www.theguardian.com/world/2020/jan/09/...
# 3      https://www.theguardian.com/world/2020/jan/14/...
# 4      https://www.theguardian.com/world/2020/jan/18/...
# ...                                                  ...
# 11474  https://www.theguardian.com/business/live/2020...
# 11475  https://www.theguardian.com/society/2020/may/1...
# 11476  https://www.theguardian.com/world/live/2020/ma...
# 11477  https://www.theguardian.com/world/live/2020/ma...
# 11478  https://www.theguardian.com/world/2020/may/18/...
#
#                                                   apiUrl  \
# 0      https://content.guardianapis.com/commentisfree...
# 1      https://content.guardianapis.com/sport/2019/de...
# 2      https://content.guardianapis.com/world/2020/ja...
# 3      https://content.guardianapis.com/world/2020/ja...
# 4      https://content.guardianapis.com/world/2020/ja...
# ...                                                  ...
# 11474  https://content.guardianapis.com/business/live...
# 11475  https://content.guardianapis.com/society/2020/...
# 11476  https://content.guardianapis.com/world/live/20...
# 11477  https://content.guardianapis.com/world/live/20...
# 11478  https://content.guardianapis.com/world/2020/ma...
#
#                                                   fields  \
# 0      {'headline': 'As a doctor I have to speak out:...
# 1      {'headline': 'Sport in 2020 calendar: your mon...
# 2      {'headline': 'China's Sars-like illness worrie...
# 3      {'headline': 'Case of mystery Sars-like illnes...
# 4      {'headline': 'Coronavirus: what airport measur...
# ...                                                  ...
# 11474  {'headline': 'Markets rally as Fed's Powell pl...
# 11475  {'headline': 'Disabled people in UK threatened...
# 11476  {'headline': 'Coronavirus live news: Italy beg...
# 11477  {'headline': 'UK coronavirus live: self-isolat...
# 11478  {'headline': 'Forces allied to Libyan governme...
#
#                                                     tags  isHosted  \
# 0      [{'id': 'commentisfree/commentisfree', 'type':...     False
# 1      [{'id': 'sport/sport', 'type': 'keyword', 'sec...     False
# 2      [{'id': 'world/epidemics', 'type': 'keyword', ...     False
# 3      [{'id': 'world/china', 'type': 'keyword', 'sec...     False
# 4      [{'id': 'world/china', 'type': 'keyword', 'sec...     False
# ...                                                  ...       ...
# 11474  [{'id': 'business/series/guardian-business-liv...     False
# 11475  [{'id': 'society/disability', 'type': 'keyword...     False
# 11476  [{'id': 'world/series/coronavirus-live', 'type...     False
# 11477  [{'id': 'politics/series/politics-live-with-an...     False
# 11478  [{'id': 'world/libya', 'type': 'keyword', 'sec...     False
#
#              pillarId pillarName  \
# 0      pillar/opinion    Opinion
# 1        pillar/sport      Sport
# 2         pillar/news       News
# 3         pillar/news       News
# 4         pillar/news       News
# ...               ...        ...
# 11474     pillar/news       News
# 11475     pillar/news       News
# 11476     pillar/news       News
# 11477     pillar/news       News
# 11478     pillar/news       News
#
#                                                 headline  \
# 0      As a doctor I have to speak out: Johnson has c...
# 1      Sport in 2020 calendar: your month-by-month gu...
# 2       China's Sars-like illness worries health experts
# 3      Case of mystery Sars-like illness found outsid...
# 4      Coronavirus: what airport measures are in plac...
# ...                                                  ...
# 11474  Markets rally as Fed's Powell pledges more amm...
# 11475  Disabled people in UK threatened with sack unl...
# 11476  Coronavirus live news: Italy begins reopening ...
# 11477  UK coronavirus live: self-isolate if you lose ...
# 11478  Forces allied to Libyan government retake key ...
#
#                                               standfirst  \
# 0      <p>The prime minister’s neglect of the NHS has...
# 1      <p>The Olympics and Paralympics head to Tokyo,...
# 2      <p>China’s viral pneumonia outbreak may have j...
# 3      <p>WHO working with Thai officials after woman...
# 4      <p>Three US airports introduce screening, foll...
# ...                                                  ...
# 11474  <p>Rolling coverage of the latest economic and...
# 11475  <p>Some employers using government’s coronavir...
# 11476  <p>Southern European countries ease lockdowns;...
# 11477  <p>Rail services ramped up in England after ch...
# 11478  <p>Loss of airbase south of Tripoli deals majo...
#
#                                                trailText  \
# 0      The prime minister’s neglect of the NHS has re...
# 1      The Olympics and Paralympics head to Tokyo, Eu...
# 2      China’s viral pneumonia outbreak may have jump...
# 3      WHO working with Thai officials after woman wh...
# 4      Three US airports introduce screening, followi...
# ...                                                  ...
# 11474   Rolling coverage of the latest economic and f...
# 11475  Some employers using government’s coronavirus ...
# 11476  Southern European countries ease lockdowns; So...
# 11477  Rail services ramped up in England after chang...
# 11478  Loss of airbase south of Tripoli deals major b...
#
#                                                   byline  \
# 0                                        Andrew Meyerson
# 1                                          Niall McVeigh
# 2                            Sarah Boseley Health editor
# 3           Lily Kuo in Beijing and Emma Graham-Harrison
# 4                            Guardian staff and agencies
# ...                                                  ...
# 11474                                     Graeme Wearden
# 11475                                       Frances Ryan
# 11476  Nick Ames (now); Jessica Murray and Helen Sull...
# 11477  Andrew Sparrow and Amy Walker (now) Simon Murp...
# 11478                  Patrick Wintour Diplomatic editor
#
#                                                     main  \
# 0      <figure class="element element-image" data-med...
# 1      <figure class="element element-image" data-med...
# 2      <figure class="element element-image" data-med...
# 3      <figure class="element element-image" data-med...
# 4      <figure class="element element-image" data-med...
# ...                                                  ...
# 11474  <figure class="element element-image" data-med...
# 11475  <figure class="element element-image" data-med...
# 11476  <figure class="element element-image" data-med...
# 11477  <figure class="element element-image" data-med...
# 11478  <figure class="element element-image" data-med...
#
#                                                     body wordcount  \
# 0      <p>10 December 2019</p> \n<p>Dear Boris Johnso...       816
# 1      <ul> \n <li><p><em>A number of sporting events...      2033
# 2      <p>The finding that the outbreak of viral pneu...       644
# 3      <p>Health authorities have confirmed that a wo...       667
# 4      <p>International airports are stepping up scre...       583
# ...                                                  ...       ...
# 11474  <div id="block-5ec260418f0886ce4f5d592c" class...      2086
# 11475  <p>Disabled people and their carers are being ...       711
# 11476  <div id="block-5ec261c58f0864e579f12f15" class...     14941
# 11477  <div id="block-5ec261f98f08a1782fa7cbae" class...      2665
# 11478  <p>Forces allied with Libya’s UN-supported gov...       728
#
#       commentable  firstPublicationDate isInappropriateForSponsorship  \
# 0           false  2019-12-10T17:43:16Z                         false
# 1            true  2019-12-31T20:00:44Z                         false
# 2             NaN  2020-01-09T19:10:17Z                         false
# 3             NaN  2020-01-14T06:44:02Z                         false
# 4             NaN  2020-01-18T05:41:07Z                         false
# ...           ...                   ...                           ...
# 11474        true  2020-05-18T07:06:02Z                         false
# 11475         NaN  2020-05-18T10:26:18Z                         false
# 11476         NaN  2020-05-17T23:25:37Z                         false
# 11477        true  2020-05-18T06:43:40Z                         false
# 11478         NaN  2020-05-18T10:23:37Z                         false
#
#       isPremoderated          lastModified productionOffice      publication  \
# 0              false  2020-04-15T08:43:23Z               UK     The Guardian
# 1              false  2020-03-02T18:50:32Z               UK  theguardian.com
# 2              false  2020-03-18T10:59:20Z               UK     The Guardian
# 3              false  2020-03-18T10:59:32Z               UK     The Guardian
# 4              false  2020-03-18T10:59:32Z               UK  theguardian.com
# ...              ...                   ...              ...              ...
# 11474          false  2020-05-18T10:25:43Z               UK  theguardian.com
# 11475          false  2020-05-18T10:27:30Z               UK  theguardian.com
# 11476          false  2020-05-18T10:27:20Z              AUS  theguardian.com
# 11477          false  2020-05-18T10:36:41Z               UK  theguardian.com
# 11478          false  2020-05-18T10:35:27Z               UK  theguardian.com
#
#                      shortUrl shouldHideAdverts showInRelatedContent  \
# 0      https://gu.com/p/cq49k             false                 true
# 1      https://gu.com/p/czqjc             false                 true
# 2      https://gu.com/p/d429m             false                 true
# 3      https://gu.com/p/d4m5m             false                 true
# 4      https://gu.com/p/d5d6c             false                 true
# ...                       ...               ...                  ...
# 11474  https://gu.com/p/dqxzv             false                 true
# 11475  https://gu.com/p/dq26e             false                 true
# 11476  https://gu.com/p/dqvd6             false                 true
# 11477  https://gu.com/p/dq2xv             false                 true
# 11478  https://gu.com/p/dq2tc             false                 true
#
#                                                thumbnail legallySensitive  \
# 0      https://media.guim.co.uk/ad103fa352c436e135b04...            false
# 1      https://media.guim.co.uk/cb495b93f083d68d1ccc5...            false
# 2      https://media.guim.co.uk/aba06df90c757a621a501...            false
# 3      https://media.guim.co.uk/392cba7928a78ab6d0b4e...            false
# 4      https://media.guim.co.uk/122b73b58101003d02122...            false
# ...                                                  ...              ...
# 11474  https://media.guim.co.uk/947b5acd32d9accd20e7d...            false
# 11475  https://media.guim.co.uk/634bf0bbdec81c3c71340...            false
# 11476  https://media.guim.co.uk/52b082ac3107a81c921ea...            false
# 11477  https://media.guim.co.uk/770abbf654ee1db8be777...            false
# 11478  https://media.guim.co.uk/6bdb51f90c5b29ca8be46...            false
#
#       lang isLive                                           bodyText  \
# 0       en   true  10 December 2019 Dear Boris Johnson, In medici...
# 1       en   true  A number of sporting events have been affected...
# 2       en   true  The finding that the outbreak of viral pneumon...
# 3       en   true  Health authorities have confirmed that a woman...
# 4       en   true  International airports are stepping up screeni...
# ...    ...    ...                                                ...
# 11474   en   true  Germany will plunge much deeper into recession...
# 11475   en   true  Disabled people and their carers are being put...
# 11476   en   true  Enforced quarantine measures at the UK border ...
# 11477   en   true  Here is the statement from all four chief medi...
# 11478   en   true  Forces allied with Libya’s UN-supported govern...
#
#       charCount shouldHideReaderRevenue showAffiliateLinks  \
# 0          4880                   false              false
# 1         11775                   false              false
# 2          3915                   false              false
# 3          4105                   false              false
# 4          3773                   false              false
# ...         ...                     ...                ...
# 11474     12625                   false              false
# 11475      4288                   false              false
# 11476     91805                   false              false
# 11477     15699                   false              false
# 11478      4418                   false              false
#
#                                               bylineHtml  \
# 0      <a href="profile/andrew-meyerson">Andrew Meyer...
# 1      <a href="profile/niall-mcveigh">Niall McVeigh</a>
# 2      <a href="profile/sarahboseley">Sarah Boseley</...
# 3      <a href="profile/lily-kuo">Lily Kuo</a> in Bei...
# 4                            Guardian staff and agencies
# ...                                                  ...
# 11474  <a href="profile/graemewearden">Graeme Wearden...
# 11475    <a href="profile/frances-ryan">Frances Ryan</a>
# 11476  <a href="profile/nick-ames">Nick Ames</a> (now...
# 11477  <a href="profile/andrewsparrow">Andrew Sparrow...
# 11478  <a href="profile/patrickwintour">Patrick Winto...
#
#            commentCloseDate displayHint newspaperPageNumber  \
# 0                       NaN         NaN                 NaN
# 1      2020-01-03T20:00:44Z   immersive                 NaN
# 2                       NaN         NaN                   6
# 3                       NaN         NaN                  38
# 4                       NaN         NaN                 NaN
# ...                     ...         ...                 ...
# 11474  2020-05-21T07:00:00Z         NaN                 NaN
# 11475                   NaN         NaN                 NaN
# 11476                   NaN         NaN                 NaN
# 11477  2020-05-21T06:45:00Z         NaN                 NaN
# 11478                   NaN         NaN                 NaN
#
#        newspaperEditionDate sensitive starRating liveBloggingNow  \
# 0                       NaN       NaN        NaN             NaN
# 1                       NaN       NaN        NaN             NaN
# 2      2020-01-10T00:00:00Z       NaN        NaN             NaN
# 3      2020-01-15T00:00:00Z       NaN        NaN             NaN
# 4                       NaN       NaN        NaN             NaN
# ...                     ...       ...        ...             ...
# 11474                   NaN       NaN        NaN            true
# 11475                   NaN       NaN        NaN             NaN
# 11476                   NaN       NaN        NaN            true
# 11477                   NaN       NaN        NaN            true
# 11478                   NaN       NaN        NaN             NaN
#
#       contributorBio
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 11474            NaN
# 11475            NaN
# 11476            NaN
# 11477            NaN
# 11478            NaN
#
# [11479 rows x 47 columns]

# %% [markdown]
# All of the columns in `data` have the same dtype, namely `object`. To be able to use the data for analysis, some columns are converted to the right type. wordcount to numeric and webPublicationDate to datetime. If we find out later that other columns need to be converted to aswell we can add code to the cell below.

# %%
data.wordcount = pd.to_numeric(data.wordcount)
data['webPublicationDate'] = pd.to_datetime(data['webPublicationDate'])

# %% [markdown]
# Below are some cells that help us explore the data. The method `value_counts()` outputs a Series containing counts of unique values. Using the method on the column `productionOffice` we see that out of the 11,479 articles in `data` right now, only 7,928 are produced by the UK production office. This is something we need to remember when we start filtering later on.

# %%
data.productionOffice.value_counts()
# Out:
# UK     7928
# AUS    2044
# US     1507
# Name: productionOffice, dtype: int64

# %% [markdown]
# Using `value_counts()` on publication shows us that most of the articles in `data` have been published on the webpage whereas there are 632 articles that have been published in "The Observer", a Sunday newspaper produced by the same newsgroup as the Guardian. This is something we also need to take into account when filtering later on.

# %%
data.publication.value_counts()
# Out:
# theguardian.com    6750
# The Guardian       4097
# The Observer        632
# Name: publication, dtype: int64

# %% [markdown]
# Using `value_counts()` in the next two cells tells us, first, that most articles in `data` are actual articles and not a liveblog or interactive content. The second cell tells us in what sections the articles has been published. An article can only be published in one section, and it shows us that most articles have been published in "World news", about 35% of all the articles. This is something that we can use later on when looking at the topical analysis.

# %%
data.type.value_counts()
# Out:
# article        10967
# liveblog         490
# interactive       22
# Name: type, dtype: int64

# %%
data.sectionName.value_counts()
# Out:
# World news                                      4061
# Opinion                                         1057
# Business                                         949
# US news                                          632
# Australia news                                   537
# Sport                                            478
# Football                                         440
# Society                                          378
# Politics                                         376
# UK news                                          303
# Environment                                      191
# Life and style                                   190
# Music                                            156
# Global development                               144
# Television & radio                               142
# Education                                        139
# Media                                            135
# Books                                            129
# Money                                            129
# News                                             128
# Film                                             118
# Technology                                       116
# Culture                                          111
# Art and design                                    93
# Stage                                             87
# Travel                                            47
# Science                                           44
# Fashion                                           43
# Food                                              27
# Law                                               26
# Games                                             16
# Global                                            14
# Membership                                         9
# Crosswords                                         5
# From the Observer                                  4
# Animals farmed                                     4
# Keep connected                                     4
# Guardian US press office                           3
# Guardian Masterclasses                             2
# The ABCs of recruiting teachers remotely           2
# Community                                          2
# Online learning revolution                         1
# All in, all together                               1
# Shelter: supporting those who are struggling       1
# In this together                                   1
# NewsWise                                           1
# Focus                                              1
# GNM press office                                   1
# Inequality                                         1
# Name: sectionName, dtype: int64

# %% [markdown]
# Below we start filtering out articles that are not relevant to our project. First of we filter out all the articles that have been produced by the UK office. Secondly, we filter out the articles that have published in 'The Observer' (This is something we could discuss, maybe leaves these in to get a broader and more representative dataset). We also remove 9 'interactive' articles since most of these don't contain any words and the rest is not useful for us. Finally, we remove the only article that has not been written in English.
# <br>If you look at the output of the second cell you can see that we filtered out 4183 articles, leaving us with 7296 articles.

# %%
data = data[data.productionOffice=='UK']
data = data[data.publication!='The Observer']
data = data[data.type!='interactive']
data = data[data.lang=='en']

# %%
data = data.reset_index(drop=True)
print(f'Remaining articles: {len(data)}')
print(f'Removed articles: {org_no_articles - len(data)}')
# Out:
# Remaining articles: 7296
# Removed articles: 4183

# %% [markdown]
# ## Descriptive statistics of the articles

# %% [markdown]
# Next up, we start looking more in depth at certain variables in the dataset. First off, the `wordcount` column. We use the `describe()` method to get descriptive statistics of the variable. If you look at the output you see that the remaining 7296 articles have average of 947 words. With a maximum of 24540 words and a minimum of 3 words. Given this output, we maybe need to look at filtering out articles that have an X number words or less. Articles with only 50 words, for example, can't really contain much information. This is something we can look into.

# %%
data.wordcount.describe()
# Out:
# count     7296.000000
# mean       947.385417
# std       1433.164181
# min          3.000000
# 25%        506.000000
# 50%        701.000000
# 75%        939.000000
# max      24540.000000
# Name: wordcount, dtype: float64

# %% [markdown]
# In the next cell we add two new columns to `data`, `publicationDay` and `publicatonWeek`. The column `webPublicationDate` is a timestamp containing the exact minute an article was published. The two new columns round this timestamp time to respectively day and weeknumber. We have to do this to make analysis easier for ourselves.

# %%
data['publicationDay'] = data.webPublicationDate.dt.date
data['publicationWeek'] = data.webPublicationDate.dt.floor('7d')

# %% [markdown]
# If we use the `describe()` method on the column `publicationDay`, we get the descriptive statistics. The articles in `data` were published on 124 unique days and the most (n=141) were published on the 25th of march, the day prince Charles tested positive for coronavirus.

# %%
print(f'First day an article was published: {data.publicationDay.min()}')
print(f'Last day an article was published: {data.publicationDay.max()}')
data.publicationDay.describe()
# Out:
# First day an article was published: 2019-12-10
# Last day an article was published: 2020-05-18
# count           7296
# unique           124
# top       2020-03-25
# freq             141
# Name: publicationDay, dtype: object

# %% [markdown]
# The next three cells create some interesting plots which gives us a small insight in the amount articles and the size(`wordcount`) of articles per day. We see a huge rise in number of articles in the beginning of March with it's peak around the 25th of march, since then news has been slowly decreasing.

# %%
resp=pd.DataFrame(data.publicationDay.value_counts()) # of respondents by survey date
resp = resp.sort_index()
plt.plot(resp)
plt.title('Articles published per day')
plt.xlabel('Days')
plt.ylabel('Number of articles')
# Out:
# Text(0, 0.5, 'Number of articles')

# %%
resp=pd.DataFrame(data.publicationWeek.value_counts()) # of respondents by survey date
resp = resp.sort_index()
plt.plot(resp)
plt.title('Articles published per week')
plt.xlabel('Weeks')
plt.ylabel('Number of articles')
# Out:
# Text(0, 0.5, 'Number of articles')

# %%
resp = data[['publicationDay','wordcount']].groupby(['publicationDay']).mean()
plt.plot(resp)
plt.title('Average wordcount per day')
plt.xlabel('Days')
plt.ylabel('wordcount')
# Out:
# Text(0, 0.5, 'wordcount')

# %% [markdown]
# # Sample for accuracy
# In order to assess our search query's accuracy to get only articles related to corona, we are sampleing 100 articles which will be manually assessed if they are actually about corona. We create a random sample of 100 articles, add a column which needs to be filled in for corona relatedness, and write this sample to a csv file for further assessement.

# %%
sample = data.sample(100)
sample['coronaRelated'] = 0
sample.to_csv('sample_articles.csv')

# %% [markdown]
# # Data to new json file
# This is the end of this notebook. The last cell creates a new json file: `articles.json`. This json files contains our dataframe `data`, with all the manipulations and filtering that we did on it. So the json file contains 49 variables about 7296 articles. You need to run this entire notebook before you can run the tags notebook since the tags notebook needs the `articles.json` file in order to run. For more information about the tags have a look there!

# %%
data.to_json('articles.json')
