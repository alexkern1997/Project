# %%
import pandas as pd
import numpy as np
import glob
from tqdm.notebook import tqdm_notebook
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Tags
# ### Explanation and creation of tags-to-articles dataframe
# In order to be able to run this notebook you need to have the `articles.json` file in the same folder. You can get this file by running the "Guardian API - Articles" notebook. The next cell loads in this file into our very familiar dataframe `data`

# %%
data = pd.read_json('articles.json')

# %% [markdown]
# Okay, so we know that the Guardian manually tags it's articles. Each tag represents a certain (sub)topic and each article can be tagged by multiple of these tags. Running the cell below gives you tags that the first article in `data` has been tagged with and also all the information that these tags contain. Have a quick look around.
# As you can see the first article is tagged with 16 tags in total. That means 16 unique topics. Each tag also has a type; for example "Tone", "Keyword" or "Type" (which means the type of article).

# %%
pd.json_normalize(data.tags[0])
# Out:
#                                        id                    type  \
# 0             commentisfree/commentisfree                    blog
# 1                             society/nhs                 keyword
# 2                         society/society                 keyword
# 3                  politics/boris-johnson                 keyword
# 4                       society/hospitals                 keyword
# 5                          society/health                 keyword
# 6                  politics/conservatives                 keyword
# 7          politics/general-election-2019                 keyword
# 8                       politics/politics                 keyword
# 9                                   uk/uk                 keyword
# 10                           tone/comment                    tone
# 11                           type/article                    type
# 12                profile/andrew-meyerson             contributor
# 13                publication/theguardian             publication
# 14                    theguardian/journal          newspaper-book
# 15            theguardian/journal/opinion  newspaper-book-section
# 16  tracking/commissioningdesk/uk-opinion                tracking
#
#         sectionId        sectionName               webTitle  \
# 0   commentisfree            Opinion                Opinion
# 1         society            Society                    NHS
# 2         society            Society                Society
# 3        politics           Politics          Boris Johnson
# 4         society            Society              Hospitals
# 5         society            Society                 Health
# 6        politics           Politics          Conservatives
# 7        politics           Politics  General election 2019
# 8        politics           Politics               Politics
# 9         uk-news            UK news                UK news
# 10            NaN                NaN                Comment
# 11            NaN                NaN                Article
# 12            NaN                NaN        Andrew Meyerson
# 13    theguardian  From the Guardian           The Guardian
# 14    theguardian  From the Guardian                Journal
# 15    theguardian  From the Guardian                Opinion
# 16            NaN                NaN             UK Opinion
#
#                                                webUrl  \
# 0   https://www.theguardian.com/commentisfree/comm...
# 1             https://www.theguardian.com/society/nhs
# 2         https://www.theguardian.com/society/society
# 3   https://www.theguardian.com/politics/boris-joh...
# 4       https://www.theguardian.com/society/hospitals
# 5          https://www.theguardian.com/society/health
# 6   https://www.theguardian.com/politics/conservat...
# 7   https://www.theguardian.com/politics/general-e...
# 8       https://www.theguardian.com/politics/politics
# 9                   https://www.theguardian.com/uk/uk
# 10           https://www.theguardian.com/tone/comment
# 11               https://www.theguardian.com/articles
# 12  https://www.theguardian.com/profile/andrew-mey...
# 13        https://www.theguardian.com/theguardian/all
# 14    https://www.theguardian.com/theguardian/journal
# 15  https://www.theguardian.com/theguardian/journa...
# 16  https://www.theguardian.com/tracking/commissio...
#
#                                                apiUrl references  \
# 0   https://content.guardianapis.com/commentisfree...         []
# 1        https://content.guardianapis.com/society/nhs         []
# 2    https://content.guardianapis.com/society/society         []
# 3   https://content.guardianapis.com/politics/bori...         []
# 4   https://content.guardianapis.com/society/hospi...         []
# 5     https://content.guardianapis.com/society/health         []
# 6   https://content.guardianapis.com/politics/cons...         []
# 7   https://content.guardianapis.com/politics/gene...         []
# 8   https://content.guardianapis.com/politics/poli...         []
# 9              https://content.guardianapis.com/uk/uk         []
# 10      https://content.guardianapis.com/tone/comment         []
# 11      https://content.guardianapis.com/type/article         []
# 12  https://content.guardianapis.com/profile/andre...         []
# 13  https://content.guardianapis.com/publication/t...         []
# 14  https://content.guardianapis.com/theguardian/j...         []
# 15  https://content.guardianapis.com/theguardian/j...         []
# 16  https://content.guardianapis.com/tracking/comm...         []
#
#                                           description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4            The latest news and comment on hospitals
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                         <p><br></p>
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  All the latest from the world's leading libera...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#                                                   bio firstName  lastName
# 0                                                 NaN       NaN       NaN
# 1                                                 NaN       NaN       NaN
# 2                                                 NaN       NaN       NaN
# 3                                                 NaN       NaN       NaN
# 4                                                 NaN       NaN       NaN
# 5                                                 NaN       NaN       NaN
# 6                                                 NaN       NaN       NaN
# 7                                                 NaN       NaN       NaN
# 8                                                 NaN       NaN       NaN
# 9                                                 NaN       NaN       NaN
# 10                                                NaN       NaN       NaN
# 11                                                NaN       NaN       NaN
# 12  <p>Andrew Meyerson is an NHS junior doctor and...    Andrew  Meyerson
# 13                                                NaN       NaN       NaN
# 14                                                NaN       NaN       NaN
# 15                                                NaN       NaN       NaN
# 16                                                NaN       NaN       NaN

# %% [markdown]
# So next up we want to tags-to-article dataframe, called `tagsToArticle`. This dataframe is row for each tags-article combination. I don't really know how to explain it better than to just demonstrating by running the following cell.

# %%
dictinary_list = []
for i in tqdm_notebook(range(len(data.tags))):
    for obj in data.tags[i]:
        obj['article_id'] =  data.id[i]
        dictinary_list.append(obj)

tagsToArticle = pd.DataFrame.from_dict(dictinary_list)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7296.0), HTML(value='')))

# %% [markdown]
# As you can see we have a total of 97,326 tags-to-article links in our dataset. The cell below counts the number of unique tags, identifying 4467 tags in our dataset. The last cell writes `tagsToArticle` to a json file if we want to use it in the future.

# %%
tagsToArticle
# Out:
#                                           id         type      sectionId  \
# 0                commentisfree/commentisfree         blog  commentisfree
# 1                                society/nhs      keyword        society
# 2                            society/society      keyword        society
# 3                     politics/boris-johnson      keyword       politics
# 4                          society/hospitals      keyword        society
# ...                                      ...          ...            ...
# 97321                            world/world      keyword          world
# 97322                           type/article         type            NaN
# 97323                              tone/news         tone            NaN
# 97324                 profile/patrickwintour  contributor            NaN
# 97325  tracking/commissioningdesk/uk-foreign     tracking            NaN
#
#       sectionName         webTitle  \
# 0         Opinion          Opinion
# 1         Society              NHS
# 2         Society          Society
# 3        Politics    Boris Johnson
# 4         Society        Hospitals
# ...           ...              ...
# 97321  World news       World news
# 97322         NaN          Article
# 97323         NaN             News
# 97324         NaN  Patrick Wintour
# 97325         NaN       UK Foreign
#
#                                                   webUrl  \
# 0      https://www.theguardian.com/commentisfree/comm...
# 1                https://www.theguardian.com/society/nhs
# 2            https://www.theguardian.com/society/society
# 3      https://www.theguardian.com/politics/boris-joh...
# 4          https://www.theguardian.com/society/hospitals
# ...                                                  ...
# 97321            https://www.theguardian.com/world/world
# 97322               https://www.theguardian.com/articles
# 97323              https://www.theguardian.com/tone/news
# 97324  https://www.theguardian.com/profile/patrickwin...
# 97325  https://www.theguardian.com/tracking/commissio...
#
#                                                   apiUrl references  \
# 0      https://content.guardianapis.com/commentisfree...         []
# 1           https://content.guardianapis.com/society/nhs         []
# 2       https://content.guardianapis.com/society/society         []
# 3      https://content.guardianapis.com/politics/bori...         []
# 4      https://content.guardianapis.com/society/hospi...         []
# ...                                                  ...        ...
# 97321       https://content.guardianapis.com/world/world         []
# 97322      https://content.guardianapis.com/type/article         []
# 97323         https://content.guardianapis.com/tone/news         []
# 97324  https://content.guardianapis.com/profile/patri...         []
# 97325  https://content.guardianapis.com/tracking/comm...         []
#
#                                               article_id  \
# 0      commentisfree/2019/dec/10/doctor-johnson-thous...
# 1      commentisfree/2019/dec/10/doctor-johnson-thous...
# 2      commentisfree/2019/dec/10/doctor-johnson-thous...
# 3      commentisfree/2019/dec/10/doctor-johnson-thous...
# 4      commentisfree/2019/dec/10/doctor-johnson-thous...
# ...                                                  ...
# 97321  world/2020/may/18/forces-allied-to-libyan-gove...
# 97322  world/2020/may/18/forces-allied-to-libyan-gove...
# 97323  world/2020/may/18/forces-allied-to-libyan-gove...
# 97324  world/2020/may/18/forces-allied-to-libyan-gove...
# 97325  world/2020/may/18/forces-allied-to-libyan-gove...
#
#                                     description  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4      The latest news and comment on hospitals
# ...                                         ...
# 97321                                       NaN
# 97322                                       NaN
# 97323                                       NaN
# 97324                                       NaN
# 97325                                       NaN
#
#                                                      bio firstName lastName  \
# 0                                                    NaN       NaN      NaN
# 1                                                    NaN       NaN      NaN
# 2                                                    NaN       NaN      NaN
# 3                                                    NaN       NaN      NaN
# 4                                                    NaN       NaN      NaN
# ...                                                  ...       ...      ...
# 97321                                                NaN       NaN      NaN
# 97322                                                NaN       NaN      NaN
# 97323                                                NaN       NaN      NaN
# 97324  <p>Patrick Wintour is diplomatic editor for th...   wintour
# 97325                                                NaN       NaN      NaN
#
#                                           bylineImageUrl  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 97321                                                NaN
# 97322                                                NaN
# 97323                                                NaN
# 97324  https://static.guim.co.uk/sys-images/Guardian/...
# 97325                                                NaN
#
#                                      bylineLargeImageUrl activeSponsorships  \
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3                                                    NaN                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 97321                                                NaN                NaN
# 97322                                                NaN                NaN
# 97323                                                NaN                NaN
# 97324  https://uploads.guim.co.uk/2017/10/09/Patrick-...                NaN
# 97325                                                NaN                NaN
#
#       twitterHandle campaignInformationType emailAddress podcast  \
# 0               NaN                     NaN          NaN     NaN
# 1               NaN                     NaN          NaN     NaN
# 2               NaN                     NaN          NaN     NaN
# 3               NaN                     NaN          NaN     NaN
# 4               NaN                     NaN          NaN     NaN
# ...             ...                     ...          ...     ...
# 97321           NaN                     NaN          NaN     NaN
# 97322           NaN                     NaN          NaN     NaN
# 97323           NaN                     NaN          NaN     NaN
# 97324           NaN                     NaN          NaN     NaN
# 97325           NaN                     NaN          NaN     NaN
#
#       paidContentType
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 97321             NaN
# 97322             NaN
# 97323             NaN
# 97324             NaN
# 97325             NaN
#
# [97326 rows x 21 columns]

# %%
print(f'Unique tags (nodes): {len(tagsToArticle.id.unique())}')
# Out:
# Unique tags (nodes): 4467

# %% [markdown]
# Let's have a look at these unique tags: A tag can be build up out of multiple layer, each layer divived by a '/'. For example, a tag regarding Boris Johnson stems from the group politics. As can be seen like below. The code in the second cell therefor adds another column to our `tagsToArticle` dataframe, namely `firstLevel` which only specifies the first level of that specific tag in that specific article. Now we can investigate the amount of unique top-levels in the tags.

# %%
tagsToArticle.id.unique()[3]
# Out:
# 'politics/boris-johnson'

# %%
tagsToArticle['firstLevel'] = tagsToArticle.id.str.split('/').str[0]

# %%
print(f'Unique top-levels: {len(tagsToArticle.firstLevel.unique())}')
# Out:
# Unique top-levels:61

# %%
tagsToArticle.firstLevel.value_counts()[:50]
# Out:
# world                     13275
# profile                    9317
# theguardian                7821
# tone                       7641
# type                       7296
# tracking                   7149
# business                   5261
# society                    5110
# uk                         4842
# politics                   4583
# publication                3870
# science                    3488
# sport                      1747
# campaign                   1565
# football                   1349
# culture                    1307
# money                      1023
# education                  1011
# environment                1004
# media                       857
# lifeandstyle                835
# commentisfree               784
# music                       769
# technology                  767
# us-news                     690
# books                       508
# artanddesign                451
# film                        437
# tv-and-radio                389
# stage                       379
# global-development          325
# uk-news                     284
# travel                      282
# law                         181
# fashion                     172
# food                        143
# news                         91
# games                        71
# inequality                   68
# australia-news               49
# cities                       44
# society-professionals        16
# membership                   16
# teacher-network              11
# crosswords                   10
# careers                       5
# info                          4
# guardian-masterclasses        4
# animals-farmed                4
# keep-connected                4
# Name: firstLevel, dtype: int64

# %% [markdown]
# It could be that there are more than 2 levels in tags. The code in the cell below looks into this.

# %%
tagsToArticle['noLevels'] = tagsToArticle.id.str.count('/')
tagsToArticle.noLevels = tagsToArticle.noLevels + 1
tagsToArticle.noLevels.value_counts()
# Out:
# 2    83180
# 3    14146
# Name: noLevels, dtype: int64

# %%
tagsToArticle.to_json('tags_articles.json')
